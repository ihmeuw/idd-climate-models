# %%
import sys
import getpass
import uuid
import os
from jobmon.client.tool import Tool # type: ignore
from pathlib import Path
from typing import Dict, Any

import idd_climate_models.constants as rfc
from idd_climate_models.dictionary_utils import parse_results
from idd_climate_models.io_compare_utils import compare_model_validation

repo_name = rfc.repo_name
package_name = rfc.package_name
DATA_DIR = rfc.RAW_DATA_PATH 
PROCESSED_DATA_PATH = rfc.PROCESSED_DATA_PATH 
SCRIPT_ROOT = rfc.REPO_ROOT / repo_name / "src" / package_name / "clean_and_split"

INPUT_DATA_TYPE = "data"
INPUT_IO_TYPE = "raw"
OUTPUT_DATA_TYPE = "data"
OUTPUT_IO_TYPE = "processed" 
DATA_SOURCE = "cmip6" 

TEST_MODE = False

def get_file_size_gb(file_path: Path) -> float:
    return os.path.getsize(file_path) / (1024**3)

def get_resource_tier(file_size_gb: float, REQUIRED_MEM_FACTOR: float = 4.0,
                      MIN_MEM_GB: float = 8.0, MAX_MEM_GB: float = 64.0) -> Dict[str, Any]:
    required_mem_gb = int(file_size_gb * REQUIRED_MEM_FACTOR) + 2 
    memory = f"{min(MAX_MEM_GB, max(MIN_MEM_GB, required_mem_gb))}G"
    if file_size_gb < 1.0:
        runtime = "10m"
        cores = 4
    elif file_size_gb < 5.0: 
        runtime = "20m" 
        cores = 4
    else: 
        runtime = "30m"
        cores = 8 
    return {
        "memory": memory,
        "cores": cores,
        "runtime": runtime
    }

# ================================================================================

# Use the unified function for validation and comparison
validation_info = compare_model_validation(
    input_data_type=INPUT_DATA_TYPE,
    input_io_type=INPUT_IO_TYPE,
    output_data_type=OUTPUT_DATA_TYPE,
    output_io_type=OUTPUT_IO_TYPE,
    data_source=DATA_SOURCE,
    verbose=True,
    produce_missing_input_report = True,
)

model_variants_to_process = validation_info["model_variants_to_process"]
input_results_for_tasks = validation_info["model_variants_to_process_dict"]["validation_results"]
input_complete_model_variants = validation_info["input_complete_model_variants"]
output_complete_model_variants = validation_info["output_complete_model_variants"]

tasks_to_run = parse_results(
    validation_dict=validation_info["model_variants_to_process_dict"],
    detail='all',
)

processed_only_model_variants = output_complete_model_variants - input_complete_model_variants
# Out:
# ================================================================================
# STEP 1.1: Input Data - Validating data raw models (Strict Check: False).
# ================================================================================
# [DATA] Starting full validation for: cmip6 (Strict Check: False)...
# [1/4] Validating CMCC-ESM2
#   ✓ CMCC-ESM2/r1i1p1f1: Complete
# [2/4] Validating EC-Earth3
#   ✓ EC-Earth3/r1i1p1f1: Complete
# [3/4] Validating MPI-ESM1-2-HR
#   ✓ MPI-ESM1-2-HR/r1i1p1f1: Complete
# [4/4] Validating MRI-ESM2-0
#   ✓ MRI-ESM2-0/r1i1p1f1: Complete
#   ✓ MRI-ESM2-0/r2i1p1f1: Complete
#   ✓ MRI-ESM2-0/r3i1p1f1: Complete
#   ✓ MRI-ESM2-0/r4i1p1f1: Complete
#   ✓ MRI-ESM2-0/r5i1p1f1: Complete
#
# ================================================================================
# Validation Summary: 8 complete, 0 incomplete model/variant combinations
# ================================================================================
#
# Validation complete for: data, raw, cmip6
# Summary: 4/4 models complete. Parsed log (up to 'grid') written to /mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/validation_log.json
#
# ================================================================================
# STEP 1.2: Output Data - Validating data processed models (Check for already completed work).
#
# ================================================================================
# [DATA] Starting full validation for: cmip6 (Strict Check: False)...
# [1/1] Validating MRI-ESM2-0
#   ✗ MRI-ESM2-0/r4i1p1f1: Incomplete (1 issues)
#
# ================================================================================
# Validation Summary: 0 complete, 1 incomplete model/variant combinations
# ================================================================================
#
# Validation complete for: data, processed, cmip6
# Summary: 0/1 models complete. Parsed log (up to 'grid') written to /mnt/team/rapidresponse/pub/tropical-storms/data/processed/cmip6/validation_log.json
#
# ================================================================================
# STEP 2: Comparing validation results and generating tasks.
# ================================================================================
#
# ✓ 8 model/variant combinations ready for processing.
# ✓ No incomplete data found - all validation checks passed!

# %%
import pandas as pd
df = pd.read_csv(rfc.TIME_BINS_WIDE_DF_PATH)

# %%
# Print all columns that are of the form: '{basin}_int'
int_columns = [col for col in df.columns if col.endswith('_int')]
print(df[int_columns])
# Out:
#      AU_int  EP_int  GL_int  NA_int  NI_int  SI_int  SP_int  WP_int
# 0        13      24      92      17       4      12       3      27
# 1        12      20      82       0       5       9       5      25
# 2        13      19      82       3       5      10       2      26
# 3        13      21      90      20       5      11       4      26
# 4        14      21      90       7       5      11       6      26
# ..      ...     ...     ...     ...     ...     ...     ...     ...
# 125      11      24      77       4       2       8       3      23
# 126      10      24      83       9       5      10       2      25
# 127      10      24      80       6       4       7       2      26
# 128      11      19      72       6       2       6       4      23
# 129      10      20      70       2       3       7       5      20
#
# [130 rows x 8 columns]

# %%
if processed_only_model_variants:
    print("\n⚠️ WARNING: Found PROCESSED models that are NOT complete in RAW data:")
    print(f"   {processed_only_model_variants}")
    print("   These models may have been processed from incomplete source data.")

print("\n" + "=" * 80)
print(f"SUMMARY: {len(input_complete_model_variants)} complete RAW models found.")
print(f"         {len(output_complete_model_variants)} complete PROCESSED models found.")
print(f"         {len(model_variants_to_process)} unique models require processing.")
print(f"         Resulting in {len(tasks_to_run)} files to process.")
print("=" * 80)

if not tasks_to_run:
    print("\n✅ Execution halted: All required files have either been processed or are incomplete in the raw data.")
    exit(0)
# Out:
# ================================================================================
# SUMMARY: 7 complete RAW models found.
#          0 complete PROCESSED models found.
#          7 unique models require processing.
#          Resulting in 1696 files to process.
# ================================================================================

# %%
tasks_to_run
# Out:
# [{'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_185001-187412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_187501-189912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_190001-192412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_192501-194912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_195001-197412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_197501-199912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'hus',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/hus/gn/Amon/hus_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_200001-201412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': '6hrPlev'},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': '6hrPlevPt'},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'day'},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/psl/gn/Amon/psl_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_185001-201412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_185001-187412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_187501-189912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_190001-192412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_192501-194912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_195001-197412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_197501-199912.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ta/gn/Amon/ta_Amon_CMCC-ESM2_historical_r1i1p1f1_gn_200001-201412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/tos/gn/Omon/tos_Omon_CMCC-ESM2_historical_r1i1p1f1_gn_185001-201412.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18500101-18511231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18520101-18531231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18540101-18551231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18560101-18571231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18580101-18591231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18600101-18611231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18620101-18631231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18640101-18651231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18660101-18671231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18680101-18691231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18700101-18711231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18720101-18731231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18740101-18751231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18760101-18771231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18780101-18791231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18800101-18811231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18820101-18831231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18840101-18851231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18860101-18871231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18880101-18891231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18900101-18911231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18920101-18931231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18940101-18951231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18960101-18971231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_18980101-18991231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19000101-19011231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19020101-19031231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19040101-19051231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19060101-19071231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19080101-19091231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19100101-19111231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19120101-19131231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19140101-19151231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19160101-19171231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19180101-19191231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19200101-19211231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19220101-19231231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19240101-19251231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19260101-19271231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19280101-19291231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19300101-19311231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19320101-19331231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19340101-19351231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19360101-19371231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19380101-19391231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19400101-19411231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19420101-19431231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19440101-19451231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19460101-19471231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19480101-19491231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19500101-19511231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19520101-19531231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19540101-19551231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19560101-19571231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19580101-19591231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19600101-19611231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19620101-19631231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19640101-19651231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19660101-19671231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19680101-19691231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19700101-19711231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19720101-19731231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19740101-19751231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19760101-19771231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19780101-19791231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19800101-19811231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19820101-19831231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19840101-19851231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19860101-19871231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19880101-19891231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19900101-19911231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19920101-19931231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19940101-19951231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19960101-19971231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_19980101-19991231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20000101-20011231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20020101-20031231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20040101-20051231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20060101-20071231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20080101-20091231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20100101-20111231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20120101-20131231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'ua',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/ua/gn/day/ua_day_CMCC-ESM2_historical_r1i1p1f1_gn_20140101-20141231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'uas',
#   'grid': 'gn',
#   'frequency': '3hr'},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'uas',
#   'grid': 'gn',
#   'frequency': '6hrPlev'},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18500101-18511231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18520101-18531231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18540101-18551231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18560101-18571231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18580101-18591231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18600101-18611231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18620101-18631231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18640101-18651231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18660101-18671231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18680101-18691231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18700101-18711231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18720101-18731231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18740101-18751231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18760101-18771231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18780101-18791231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18800101-18811231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18820101-18831231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18840101-18851231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18860101-18871231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18880101-18891231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18900101-18911231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18920101-18931231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18940101-18951231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18960101-18971231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_18980101-18991231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19000101-19011231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19020101-19031231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19040101-19051231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19060101-19071231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19080101-19091231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19100101-19111231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19120101-19131231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19140101-19151231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19160101-19171231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19180101-19191231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19200101-19211231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19220101-19231231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19240101-19251231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19260101-19271231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'variable': 'va',
#   'grid': 'gn',
#   'frequency': 'day',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/CMCC-ESM2/r1i1p1f1/historical/va/gn/day/va_day_CMCC-ESM2_historical_r1i1p1f1_gn_19280101-19291231.nc',
#   'fill_required': False},
#  {'model': 'CMCC-ESM2',
# ...
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203501-203912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204001-204412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204501-204912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205001-205412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205501-205912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206001-206412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206501-206912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207001-207412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207501-207912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208001-208412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208501-208912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209001-209412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209501-209912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'psl',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/psl/gn/Amon/psl_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_210001-210012.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_201501-201912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202001-202412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202501-202912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203001-203412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203501-203912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204001-204412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204501-204912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205001-205412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205501-205912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206001-206412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206501-206912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207001-207412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207501-207912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208001-208412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208501-208912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209001-209412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_209501-209912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'ta',
#   'grid': 'gn',
#   'frequency': 'Amon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/ta/gn/Amon/ta_Amon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_210001-210012.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_201501-201912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202001-202412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_202501-202912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203001-203412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_203501-203912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204001-204412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_204501-204912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205001-205412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_205501-205912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206001-206412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_206501-206912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207001-207412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_207501-207912.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208001-208412.nc',
#   'fill_required': False},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'variable': 'tos',
#   'grid': 'gn',
#   'frequency': 'Omon',
#   'file_path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/MPI-ESM1-2-HR/r1i1p1f1/ssp585/tos/gn/Omon/tos_Omon_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_208501-208912.nc',
#   'fill_required': False},
#  ...]

# %%
    
    





# Filter and print
results = validation_info['input_validation_dict']['validation_results']
incomplete_only = {}

for model_name, model_data in results.items():
    filtered = filter_to_incomplete_only(model_data)
    if filtered is not None:
        incomplete_only[model_name] = filtered

incomplete_only
# Out:
# {'EC-Earth3': {'variant': {'r1i1p1f1': {'scenario': {'ssp126': {'variable': {'ua': {'complete': False,
#         'issues': ["Grid Priority: Found multiple grids. Selecting highest priority: 'gr'"],
#         'grid': {'gr': {'complete': False,
#           'issues': [],
#           'frequency': {'day': {'complete': False,
#             'files': [{'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20220101-20221231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20250101-20251231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20270101-20271231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20290101-20291231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20300101-20301231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20310101-20311231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20330101-20331231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20350101-20351231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20360101-20361231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20370101-20371231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20390101-20391231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20400101-20401231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20450101-20451231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20460101-20461231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20470101-20471231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20500101-20501231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20530101-20531231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20560101-20561231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20610101-20611231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20680101-20681231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20760101-20761231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20770101-20771231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20800101-20801231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20820101-20821231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20850101-20851231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20870101-20871231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20880101-20881231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20910101-20911231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20930101-20931231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20950101-20951231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20960101-20961231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20970101-20971231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_20980101-20981231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/ua/gr/day/ua_day_EC-Earth3_ssp126_r1i1p1f1_gr_21000101-21001231.nc',
#               'fill_required': False}],
#             'issues': ['Coverage starts too late: 20220101, expected by: 20150101']}}}}},
#        'va': {'complete': False,
#         'issues': ["Grid Priority: Found multiple grids. Selecting highest priority: 'gr'"],
#         'grid': {'gr': {'complete': False,
#           'issues': [],
#           'frequency': {'day': {'complete': False,
#             'files': [{'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20180101-20181231.nc',
#               'fill_required': True},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20220101-20221231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20230101-20231231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20250101-20251231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20280101-20281231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20300101-20301231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20310101-20311231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20350101-20351231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20360101-20361231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20370101-20371231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20410101-20411231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20430101-20431231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20490101-20491231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20500101-20501231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20520101-20521231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20530101-20531231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20540101-20541231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20580101-20581231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20590101-20591231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20830101-20831231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20840101-20841231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20860101-20861231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20880101-20881231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20910101-20911231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20930101-20931231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20950101-20951231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20960101-20961231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20970101-20971231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp126/va/gr/day/va_day_EC-Earth3_ssp126_r1i1p1f1_gr_20990101-20991231.nc',
#               'fill_required': True}],
#             'issues': ['Coverage starts a little late: 20180101, expected by: 20150101',
#              'Coverage ends a little early: 20991231, expected until: 21001231',
#              'Gap between 20181231 and 20220101']}}}}}}},
#      'ssp585': {'variable': {'ua': {'complete': False,
#         'issues': ["Grid Priority: Found multiple grids. Selecting highest priority: 'gr'"],
#         'grid': {'gr': {'complete': False,
#           'issues': [],
#           'frequency': {'day': {'complete': False,
#             'files': [{'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20190101-20191231.nc',
#               'fill_required': True},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20210101-20211231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20310101-20311231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20320101-20321231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20370101-20371231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20390101-20391231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20400101-20401231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20440101-20441231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20500101-20501231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20600101-20601231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20620101-20621231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20640101-20641231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20690101-20691231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20720101-20721231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20760101-20761231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20790101-20791231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20840101-20841231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20860101-20861231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20900101-20901231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20960101-20961231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_20980101-20981231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/ua/gr/day/ua_day_EC-Earth3_ssp585_r1i1p1f1_gr_21000101-21001231.nc',
#               'fill_required': False}],
#             'issues': ['Coverage starts a little late: 20190101, expected by: 20150101',
#              'Gap between 20191231 and 20210101']}}}}},
#        'va': {'complete': False,
#         'issues': ["Grid Priority: Found multiple grids. Selecting highest priority: 'gr'"],
#         'grid': {'gr': {'complete': False,
#           'issues': [],
#           'frequency': {'day': {'complete': False,
#             'files': [{'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20940101-20941231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20950101-20951231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20960101-20961231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20970101-20971231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20980101-20981231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_20990101-20991231.nc',
#               'fill_required': False},
#              {'path': '/mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/EC-Earth3/r1i1p1f1/ssp585/va/gr/day/va_day_EC-Earth3_ssp585_r1i1p1f1_gr_21000101-21001231.nc',
#               'fill_required': False}],
#             'issues': ['Coverage starts too late: 20940101, expected by: 20150101']}}}}}}}}}}}}

# %%
from datetime import datetime, timedelta
import re
from pathlib import Path
import idd_climate_models.constants as rfc
from idd_climate_models.validation_functions import (
    int_to_date, 
    is_monthly, 
    extract_date_ranges
)

START_YEAR = rfc.START_YEAR
END_YEAR = rfc.END_YEAR




import pandas as pd

import pandas as pd



# Run the analysis
records = analyze_incomplete_variables(incomplete_only)

# Create DataFrame
missing_years_df = pd.DataFrame(records)

# Save to CSV
output_path = DATA_DIR / DATA_SOURCE / "missing_variables.csv"
missing_years_df.to_csv(output_path, index=False)
os.chmod(output_path, 0o775)

# Display summary
print(f"Total missing year entries: {len(missing_years_df)}")
print(f"Saved to: {output_path}")
print(f"\nFirst 50 rows:")
missing_years_df.head(50)
# Out:
# Total missing year entries: 252
# Saved to: /mnt/team/rapidresponse/pub/tropical-storms/data/raw/cmip6/missing_variables.csv
#
# First 50 rows:
#         Model   Variant Scenario Variable Grid Frequency  Missing_Year
# 0   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2015
# 1   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2016
# 2   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2017
# 3   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2018
# 4   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2019
# 5   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2020
# 6   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2021
# 7   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2023
# 8   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2024
# 9   EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2026
# 10  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2028
# 11  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2032
# 12  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2034
# 13  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2038
# 14  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2041
# 15  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2042
# 16  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2043
# 17  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2044
# 18  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2048
# 19  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2049
# 20  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2051
# 21  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2052
# 22  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2054
# 23  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2055
# 24  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2057
# 25  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2058
# 26  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2059
# 27  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2060
# 28  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2062
# 29  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2063
# 30  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2064
# 31  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2065
# 32  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2066
# 33  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2067
# 34  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2069
# 35  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2070
# 36  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2071
# 37  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2072
# 38  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2073
# 39  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2074
# 40  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2075
# 41  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2078
# 42  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2079
# 43  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2081
# 44  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2083
# 45  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2084
# 46  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2086
# 47  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2089
# 48  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2090
# 49  EC-Earth3  r1i1p1f1   ssp126       ua   gr       day          2092

# %%
# Let's debug - check if 'zg' actually has any complete: False
def find_all_complete_values(obj, path=""):
    """Find all 'complete' values in the nested structure"""
    results = []
    if isinstance(obj, dict):
        if 'complete' in obj:
            results.append((path, obj['complete']))
        for key, value in obj.items():
            results.extend(find_all_complete_values(value, f"{path}.{key}" if path else key))
    return results

# Check what's actually in 'zg'
if 'zg' in incomplete:
    print("Complete values in 'zg':")
    for path, value in find_all_complete_values(incomplete['zg']):
        print(f"  {path}: {value}")
