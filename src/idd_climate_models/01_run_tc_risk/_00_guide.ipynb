# %% [raw]
# # 01_run_tc_risk
#  - For each model/variant/scenario, pick time-period chunk sizes
#  - For each time-period chunk, create sub-folders by time-period within the model/variant/scenario folder that contains all the pertinent variables for that time-period chunk
#  - Create folders for output
#  - Create the model run wrapper to run tc_risk on each time-period chunk folder for X draws
#     - Run once globally
#     - Then for each basin run X times
#  - Combine the outputs? Process them?
