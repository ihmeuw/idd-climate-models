# %% [raw]
# import os
# import json
# from datetime import datetime
#
# import idd_climate_models.constants as rfc
# from idd_climate_models.processing_log import load_processing_log

# %% [raw]
# PROCESSED_DATA_PATH = rfc.PROCESSED_DATA_PATH
# load_processing_log(PROCESSED_DATA_PATH)
