# %% [markdown]
# # Test Updated Output Checking Logic for TC-Risk Pipeline
#
# This notebook tests the improved output-checking functions:
# 1. Level 3 must be finished (both env_wnd_*.nc and thermo_*.nc exist)
# 2. Level 4 is only checked within finished Level 3 runs
# 3. Level 4 completeness requires NUM_DRAWS + 1 files (251 files)
# 4. Report file counts per basin/model/variant/scenario/time_period

# %%
import pandas as pd
from pathlib import Path
import sys

# Add the source directory to path
sys.path.insert(0, '/ihme/homes/bcreiner/repos/idd-climate-models/src')

import idd_climate_models.constants as rfc

# Import constants
TC_RISK_OUTPUT_PATH = rfc.TC_RISK_OUTPUT_PATH
NUM_DRAWS = rfc.NUM_DRAWS
TIME_BINS_DF_PATH = rfc.TIME_BINS_DF_PATH
BASINS = ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP']
DATA_SOURCE = 'cmip6'

print(f"TC_RISK_OUTPUT_PATH: {TC_RISK_OUTPUT_PATH}")
print(f"NUM_DRAWS: {NUM_DRAWS}")
print(f"NUM_DRAWS + 1 (required for Level 4): {NUM_DRAWS + 1}")
print(f"TIME_BINS_DF_PATH: {TIME_BINS_DF_PATH}")
# Out:
# TC_RISK_OUTPUT_PATH: /mnt/team/rapidresponse/pub/tropical-storms/tc_risk/output
# NUM_DRAWS: 250
# NUM_DRAWS + 1 (required for Level 4): 251
# TIME_BINS_DF_PATH: /mnt/team/rapidresponse/pub/tropical-storms/tempestextremes/outputs/cmip6/time_bins.csv

# %% [markdown]
# ## Load time bins and build task list

# %%
# Load time bins
time_bins_df = pd.read_csv(TIME_BINS_DF_PATH)

# Filter to BayesPoisson method only
time_bins_df = time_bins_df[time_bins_df['method'] == 'BayesPoisson']

# Create time_period column
time_bins_df['time_period'] = time_bins_df['start_year'].astype(str) + '-' + time_bins_df['end_year'].astype(str)

# Get unique combinations
unique_time_bins = time_bins_df[['model', 'variant', 'scenario', 'time_period', 'start_year', 'end_year']].drop_duplicates()

print(f"Total unique (model, variant, scenario, time_period) combinations: {len(unique_time_bins)}")
print(f"\nFirst few rows:")
print(unique_time_bins.head(10))
# Out:
# Total unique (model, variant, scenario, time_period) combinations: 130
#
# First few rows:
#         model   variant    scenario time_period  start_year  end_year
# 0   CMCC-ESM2  r1i1p1f1  historical   1970-1986        1970      1986
# 8   CMCC-ESM2  r1i1p1f1  historical   1987-2001        1987      2001
# 16  CMCC-ESM2  r1i1p1f1  historical   2002-2014        2002      2014
# 24  CMCC-ESM2  r1i1p1f1      ssp126   2015-2026        2015      2026
# 32  CMCC-ESM2  r1i1p1f1      ssp126   2027-2036        2027      2036
# 40  CMCC-ESM2  r1i1p1f1      ssp126   2037-2046        2037      2046
# 48  CMCC-ESM2  r1i1p1f1      ssp126   2047-2058        2047      2058
# 56  CMCC-ESM2  r1i1p1f1      ssp126   2059-2076        2059      2076
# 64  CMCC-ESM2  r1i1p1f1      ssp126   2077-2100        2077      2100
# 72  CMCC-ESM2  r1i1p1f1      ssp245   2015-2026        2015      2026

# %% [markdown]
# ## Define improved output checking functions

# %%
def check_level3_output_finished(model, variant, scenario, time_period, data_source="cmip6"):
    """
    Check if Level 3 (global TC-risk) has finished successfully.
    Returns True if finished (has both env_wnd and thermo files), False otherwise.
    """
    output_path = TC_RISK_OUTPUT_PATH / data_source / model / variant / scenario / time_period
    if not output_path.exists():
        return False
    
    # Check for required Level 3 output files
    env_wnd_files = list(output_path.glob("env_wnd_*.nc"))
    thermo_files = list(output_path.glob("thermo_*.nc"))
    
    # Complete if both files exist
    return len(env_wnd_files) > 0 and len(thermo_files) > 0

def get_level4_basin_file_count(model, variant, scenario, time_period, basin, data_source="cmip6"):
    """
    Get the number of files in a Level 4 basin output folder.
    Returns the count, or -1 if folder doesn't exist.
    """
    output_path = TC_RISK_OUTPUT_PATH / data_source / model / variant / scenario / time_period / basin
    if not output_path.exists():
        return -1
    
    files = list(output_path.glob("*.nc"))
    return len(files)

def check_level4_output_complete(model, variant, scenario, time_period, basin, data_source="cmip6"):
    """
    Check if Level 4 (basin TC-risk) output is complete.
    Returns True if has NUM_DRAWS + 1 files, False otherwise.
    """
    file_count = get_level4_basin_file_count(model, variant, scenario, time_period, basin, data_source)
    return file_count >= NUM_DRAWS + 1

print("Output checking functions defined successfully")
# Out:
# Output checking functions defined successfully

# %% [markdown]
# ## Build all tasks from time bins

# %%
# Build all tasks from time bins
all_tasks = []
for _, row in unique_time_bins.iterrows():
    all_tasks.append({
        'model': row['model'],
        'variant': row['variant'],
        'scenario': row['scenario'],
        'time_period': row['time_period'],
    })

print(f"Total tasks: {len(all_tasks)}")
# Out:
# Total tasks: 130

# %% [markdown]
# ## TEST 1: Check Level 3 Completion (IMPROVED)

# %%
# Check Level 3 outputs - MUST HAVE BOTH env_wnd and thermo files
level3_finished = []
level3_not_finished = []

for task in all_tasks:
    model = task['model']
    variant = task['variant']
    scenario = task['scenario']
    time_period = task['time_period']
    
    if check_level3_output_finished(model, variant, scenario, time_period, DATA_SOURCE):
        level3_finished.append(task)
    else:
        level3_not_finished.append(task)

print(f"\n=== LEVEL 3 OUTPUT STATUS ===")
print(f"Finished (ready for L4):   {len(level3_finished)}")
print(f"Not finished (skip L4):    {len(level3_not_finished)}")
print(f"Total:                     {len(all_tasks)}")

if level3_finished:
    print(f"\nFirst 10 finished Level 3 tasks (L4 can run on these):")
    for task in level3_finished[:10]:
        print(f"  {task['model']}/{task['variant']}/{task['scenario']}/{task['time_period']}")

if level3_not_finished:
    print(f"\nFirst 10 NOT finished Level 3 tasks (L4 will NOT run on these):")
    for task in level3_not_finished[:10]:
        print(f"  {task['model']}/{task['variant']}/{task['scenario']}/{task['time_period']}")
# Out:
# === LEVEL 3 OUTPUT STATUS ===
# Finished (ready for L4):   108
# Not finished (skip L4):    22
# Total:                     130
#
# First 10 finished Level 3 tasks (L4 can run on these):
#   CMCC-ESM2/r1i1p1f1/historical/1970-1986
#   CMCC-ESM2/r1i1p1f1/historical/1987-2001
#   CMCC-ESM2/r1i1p1f1/historical/2002-2014
#   CMCC-ESM2/r1i1p1f1/ssp126/2015-2026
#   CMCC-ESM2/r1i1p1f1/ssp126/2027-2036
#   CMCC-ESM2/r1i1p1f1/ssp126/2037-2046
#   CMCC-ESM2/r1i1p1f1/ssp126/2047-2058
#   CMCC-ESM2/r1i1p1f1/ssp126/2059-2076
#   CMCC-ESM2/r1i1p1f1/ssp245/2015-2026
#   CMCC-ESM2/r1i1p1f1/ssp245/2027-2036
#
# First 10 NOT finished Level 3 tasks (L4 will NOT run on these):
#   CMCC-ESM2/r1i1p1f1/ssp126/2077-2100
#   MRI-ESM2-0/r1i1p1f1/ssp126/2015-2042
#   MRI-ESM2-0/r1i1p1f1/ssp126/2043-2071
#   MRI-ESM2-0/r1i1p1f1/ssp126/2072-2100
#   MRI-ESM2-0/r2i1p1f1/historical/1970-1999
#   MRI-ESM2-0/r2i1p1f1/ssp126/2029-2055
#   MRI-ESM2-0/r2i1p1f1/ssp126/2071-2100
#   MRI-ESM2-0/r2i1p1f1/ssp245/2015-2044
#   MRI-ESM2-0/r2i1p1f1/ssp245/2073-2100
#   MRI-ESM2-0/r3i1p1f1/historical/1986-2014

# %% [markdown]
# ## TEST 2: Check Level 4 Basin Completeness (IMPROVED)
# ONLY for tasks whose Level 3 finished, check if basins have NUM_DRAWS + 1 files

# %%
# Check Level 4 outputs ONLY for finished Level 3 tasks
level4_tasks_with_incomplete_basins = []
level4_fully_complete = []

for task in level3_finished:
    model = task['model']
    variant = task['variant']
    scenario = task['scenario']
    time_period = task['time_period']
    
    basin_file_counts = {}
    incomplete_basins = []
    
    for basin in BASINS:
        file_count = get_level4_basin_file_count(model, variant, scenario, time_period, basin, DATA_SOURCE)
        basin_file_counts[basin] = file_count
        
        # Incomplete if fewer than NUM_DRAWS + 1 files
        if file_count < NUM_DRAWS + 1:
            incomplete_basins.append(basin)
    
    if incomplete_basins:
        level4_tasks_with_incomplete_basins.append({
            **task,
            'incomplete_basins': incomplete_basins,
            'basin_file_counts': basin_file_counts
        })
    else:
        level4_fully_complete.append(task)

print(f"\n=== LEVEL 4 OUTPUT STATUS (Only for finished Level 3) ===")
print(f"Combos with incomplete basins: {len(level4_tasks_with_incomplete_basins)}")
print(f"Combos fully complete:         {len(level4_fully_complete)}")
print(f"Total checked (L3 finished):   {len(level3_finished)}")
print(f"\nRequired files per basin: {NUM_DRAWS + 1}")
# Out:
# === LEVEL 4 OUTPUT STATUS (Only for finished Level 3) ===
# Combos with incomplete basins: 108
# Combos fully complete:         0
# Total checked (L3 finished):   108
#
# Required files per basin: 251

# %%
level4_tasks_with_incomplete_basins
# Out:
# [{'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1970-1986',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 37,
#    'NA': 27,
#    'NI': 53,
#    'SI': 38,
#    'AU': 41,
#    'SP': 54,
#    'WP': 37}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1987-2001',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 42,
#    'NA': 77,
#    'NI': 54,
#    'SI': 49,
#    'AU': 47,
#    'SP': 49,
#    'WP': 38}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '2002-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 46,
#    'NA': 55,
#    'NI': 53,
#    'SI': 48,
#    'AU': 46,
#    'SP': 70,
#    'WP': 46}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2026',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 48,
#    'NA': 26,
#    'NI': 71,
#    'SI': 63,
#    'AU': 70,
#    'SP': 64,
#    'WP': 37}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2027-2036',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 51,
#    'NA': 52,
#    'NI': 69,
#    'SI': 62,
#    'AU': 69,
#    'SP': 77,
#    'WP': 64}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2037-2046',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 47,
#    'NA': 26,
#    'NI': 84,
#    'SI': 61,
#    'AU': 61,
#    'SP': 71,
#    'WP': 55}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2047-2058',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 40,
#    'NA': 52,
#    'NI': 58,
#    'SI': 60,
#    'AU': 48,
#    'SP': 23,
#    'WP': 21}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2059-2076',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2026',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 39,
#    'NA': 44,
#    'NI': 54,
#    'SI': 48,
#    'AU': 48,
#    'SP': 61,
#    'WP': 44}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2027-2036',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 56,
#    'NA': 32,
#    'NI': 81,
#    'SI': 74,
#    'AU': 69,
#    'SP': 89,
#    'WP': 74}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2037-2052',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 39,
#    'NA': 29,
#    'NI': 45,
#    'SI': 39,
#    'AU': 38,
#    'SP': 46,
#    'WP': 35}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2053-2065',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 29,
#    'NA': 30,
#    'NI': 57,
#    'SI': 54,
#    'AU': 50,
#    'SP': 59,
#    'WP': 48}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2066-2075',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 43,
#    'NA': 30,
#    'NI': 71,
#    'SI': 66,
#    'AU': 54,
#    'SP': 71,
#    'WP': 53}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2076-2090',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 29,
#    'NA': 52,
#    'NI': 17,
#    'SI': 17,
#    'AU': 16,
#    'SP': 18,
#    'WP': 52}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2091-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 42,
#    'NA': 41,
#    'NI': 68,
#    'SI': 71,
#    'AU': 55,
#    'SP': 71,
#    'WP': 55}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2029',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 39,
#    'NA': 42,
#    'NI': 55,
#    'SI': 47,
#    'AU': 49,
#    'SP': 62,
#    'WP': 38}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2030-2041',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 37,
#    'NA': 92,
#    'NI': 65,
#    'SI': 52,
#    'AU': 52,
#    'SP': 63,
#    'WP': 60}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2042-2058',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 22,
#    'NA': 14,
#    'NI': 39,
#    'SI': 29,
#    'AU': 38,
#    'SP': 41,
#    'WP': 34}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2059-2069',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 44,
#    'NA': 67,
#    'NI': 84,
#    'SI': 62,
#    'AU': 58,
#    'SP': 69,
#    'WP': 65}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2070-2079',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 40,
#    'NA': 36,
#    'NI': 79,
#    'SI': 91,
#    'AU': 71,
#    'SP': 76,
#    'WP': 79}},
#  {'model': 'CMCC-ESM2',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2080-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 16,
#    'NA': 22,
#    'NI': 38,
#    'SI': 35,
#    'AU': 26,
#    'SP': 30,
#    'WP': 26}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1970-1987',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 30,
#    'NA': 21,
#    'NI': 34,
#    'SI': 35,
#    'AU': 31,
#    'SP': 46,
#    'WP': 28}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1988-1999',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 46,
#    'NA': 72,
#    'NI': 60,
#    'SI': 66,
#    'AU': 49,
#    'SP': 60,
#    'WP': 44}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '2000-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 35,
#    'NA': 40,
#    'NI': 52,
#    'SI': 48,
#    'AU': 46,
#    'SP': 75,
#    'WP': 47}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2031',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 35,
#    'NA': 53,
#    'NI': 49,
#    'SI': 41,
#    'AU': 41,
#    'SP': 50,
#    'WP': 35}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2032-2056',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2057-2086',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2087-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 43,
#    'NA': 48,
#    'NI': 57,
#    'SI': 67,
#    'AU': 58,
#    'SP': 74,
#    'WP': 42}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2044',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2045-2070',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2071-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2031',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 26,
#    'NA': 35,
#    'NI': 35,
#    'SI': 32,
#    'AU': 32,
#    'SP': 41,
#    'WP': 34}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2032-2060',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2061-2090',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'EC-Earth3',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2091-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 57,
#    'NA': 62,
#    'NI': 77,
#    'SI': 90,
#    'AU': 64,
#    'SP': 76,
#    'WP': 58}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1965-1987',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1988-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2024',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 49,
#    'NA': 79,
#    'NI': 66,
#    'SI': 60,
#    'AU': 54,
#    'SP': 68,
#    'WP': 51}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2025-2038',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 43,
#    'NA': 32,
#    'NI': 50,
#    'SI': 45,
#    'AU': 39,
#    'SP': 51,
#    'WP': 38}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2039-2051',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 38,
#    'NA': 46,
#    'NI': 46,
#    'SI': 39,
#    'AU': 35,
#    'SP': 53,
#    'WP': 38}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2052-2065',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 33,
#    'NA': 50,
#    'NI': 45,
#    'SI': 47,
#    'AU': 37,
#    'SP': 50,
#    'WP': 39}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2066-2089',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2090-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 46,
#    'NA': 65,
#    'NI': 77,
#    'SI': 76,
#    'AU': 47,
#    'SP': 78,
#    'WP': 55}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2024',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 52,
#    'NA': 69,
#    'NI': 74,
#    'SI': 61,
#    'AU': 59,
#    'SP': 73,
#    'WP': 50}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2025-2034',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 49,
#    'NA': 42,
#    'NI': 64,
#    'SI': 69,
#    'AU': 63,
#    'SP': 73,
#    'WP': 55}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2035-2050',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 30,
#    'NA': 36,
#    'NI': 38,
#    'SI': 37,
#    'AU': 28,
#    'SP': 45,
#    'WP': 31}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2051-2078',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2079-2090',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 50,
#    'NA': 73,
#    'NI': 65,
#    'SI': 56,
#    'AU': 59,
#    'SP': 81,
#    'WP': 55}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2091-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 54,
#    'NA': 50,
#    'NI': 77,
#    'SI': 69,
#    'AU': 59,
#    'SP': 80,
#    'WP': 63}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2028',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 35,
#    'NA': 29,
#    'NI': 58,
#    'SI': 39,
#    'AU': 35,
#    'SP': 50,
#    'WP': 38}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2029-2039',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 47,
#    'NA': 52,
#    'NI': 55,
#    'SI': 58,
#    'AU': 42,
#    'SP': 64,
#    'WP': 42}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2040-2050',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 46,
#    'NA': 88,
#    'NI': 54,
#    'SI': 58,
#    'AU': 45,
#    'SP': 62,
#    'WP': 50}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2051-2061',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 65,
#    'NA': 39,
#    'NI': 71,
#    'SI': 54,
#    'AU': 50,
#    'SP': 61,
#    'WP': 50}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2062-2074',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 36,
#    'NA': 58,
#    'NI': 47,
#    'SI': 47,
#    'AU': 35,
#    'SP': 44,
#    'WP': 34}},
#  {'model': 'MPI-ESM1-2-HR',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2075-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1970-1980',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 41,
#    'NA': 60,
#    'NI': 36,
#    'SI': 35,
#    'AU': 32,
#    'SP': 46,
#    'WP': 46}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1981-1990',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 48,
#    'NA': 49,
#    'NI': 65,
#    'SI': 47,
#    'AU': 44,
#    'SP': 55,
#    'WP': 47}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1991-2002',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 39,
#    'NA': 59,
#    'NI': 44,
#    'SI': 36,
#    'AU': 40,
#    'SP': 32,
#    'WP': 33}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'historical',
#   'time_period': '2003-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 47,
#    'NA': 40,
#    'NI': 54,
#    'SI': 50,
#    'AU': 34,
#    'SP': 50,
#    'WP': 36}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2031',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2032-2050',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2051-2075',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2076-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2026',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 37,
#    'NA': 59,
#    'NI': 47,
#    'SI': 40,
#    'AU': 38,
#    'SP': 43,
#    'WP': 30}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2027-2036',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 56,
#    'NA': 65,
#    'NI': 62,
#    'SI': 53,
#    'AU': 45,
#    'SP': 53,
#    'WP': 42}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2037-2054',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2055-2064',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 55,
#    'NA': 109,
#    'NI': 74,
#    'SI': 73,
#    'AU': 45,
#    'SP': 73,
#    'WP': 42}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2065-2087',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r1i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2088-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 32,
#    'NA': 55,
#    'NI': 44,
#    'SI': 46,
#    'AU': 39,
#    'SP': 34,
#    'WP': 34}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'historical',
#   'time_period': '2000-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 31,
#    'NA': 39,
#    'NI': 37,
#    'SI': 29,
#    'AU': 26,
#    'SP': 40,
#    'WP': 28}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2028',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 23,
#    'NA': 28,
#    'NI': 28,
#    'SI': 26,
#    'AU': 25,
#    'SP': 27,
#    'WP': 22}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2056-2070',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 26,
#    'NA': 33,
#    'NI': 28,
#    'SI': 27,
#    'AU': 21,
#    'SP': 22,
#    'WP': 24}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2045-2059',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 30,
#    'NA': 32,
#    'NI': 34,
#    'SI': 43,
#    'AU': 31,
#    'SP': 32,
#    'WP': 33}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2060-2072',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 27,
#    'NA': 50,
#    'NI': 43,
#    'SI': 41,
#    'AU': 32,
#    'SP': 25,
#    'WP': 33}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2035',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2036-2056',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2057-2079',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r2i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2080-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1970-1985',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2038',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2066-2084',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2085-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 30,
#    'NA': 33,
#    'NI': 27,
#    'SI': 27,
#    'AU': 30,
#    'SP': 31,
#    'WP': 30}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2033',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2034-2047',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 34,
#    'NA': 66,
#    'NI': 45,
#    'SI': 38,
#    'AU': 33,
#    'SP': 34,
#    'WP': 28}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2036',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2064-2086',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r3i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2087-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 35,
#    'NA': 63,
#    'NI': 56,
#    'SI': 47,
#    'AU': 38,
#    'SP': 32,
#    'WP': 36}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1970-1980',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 40,
#    'NA': 44,
#    'NI': 55,
#    'SI': 38,
#    'AU': 28,
#    'SP': 40,
#    'WP': 33}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1981-1990',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 43,
#    'NA': 80,
#    'NI': 43,
#    'SI': 43,
#    'AU': 38,
#    'SP': 49,
#    'WP': 37}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'historical',
#   'time_period': '1991-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2036',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2037-2056',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2087-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 31,
#    'NA': 64,
#    'NI': 47,
#    'SI': 36,
#    'AU': 31,
#    'SP': 42,
#    'WP': 26}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2029',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2030-2050',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2078-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2015-2038',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2065-2084',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r4i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2085-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'historical',
#   'time_period': '2000-2014',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2015-2027',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 33,
#    'NA': 31,
#    'NI': 45,
#    'SI': 38,
#    'AU': 34,
#    'SP': 26,
#    'WP': 30}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2028-2047',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2048-2076',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp126',
#   'time_period': '2077-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2015-2030',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp245',
#   'time_period': '2083-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2041-2061',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': -1,
#    'NA': -1,
#    'NI': -1,
#    'SI': -1,
#    'AU': -1,
#    'SP': -1,
#    'WP': -1}},
#  {'model': 'MRI-ESM2-0',
#   'variant': 'r5i1p1f1',
#   'scenario': 'ssp585',
#   'time_period': '2088-2100',
#   'incomplete_basins': ['EP', 'NA', 'NI', 'SI', 'AU', 'SP', 'WP'],
#   'basin_file_counts': {'EP': 31,
#    'NA': 49,
#    'NI': 46,
#    'SI': 45,
#    'AU': 37,
#    'SP': 28,
#    'WP': 40}}]

# %% [markdown]
# ## TEST 3: Detailed Level 4 Basin File Count Analysis

# %%
# Show detailed file counts for incomplete Level 4 tasks
if level4_tasks_with_incomplete_basins:
    print(f"\nDetailed Level 4 status (showing incomplete basins):")
    print(f"Displaying first 15 combos with incomplete basins:\n")
    
    for task in level4_tasks_with_incomplete_basins[:15]:
        print(f"  {task['model']}/{task['variant']}/{task['scenario']}/{task['time_period']}")
        for basin in BASINS:
            count = task['basin_file_counts'][basin]
            if count == -1:
                status = "✗ MISSING"
                print(f"    {basin}: --- (folder doesn't exist) {status}")
            elif count >= NUM_DRAWS + 1:
                status = "✓ COMPLETE"
                print(f"    {basin}: {count:3d}/{NUM_DRAWS + 1} files {status}")
            else:
                status = f"✗ INCOMPLETE ({NUM_DRAWS + 1 - count} more needed)"
                print(f"    {basin}: {count:3d}/{NUM_DRAWS + 1} files {status}")
        print()
else:
    print("\nNo incomplete Level 4 tasks found!")
# Out:
# Detailed Level 4 status (showing incomplete basins):
# Displaying first 15 combos with incomplete basins:
#
#   CMCC-ESM2/r1i1p1f1/historical/1970-1986
#     EP:  37/251 files ✗ INCOMPLETE (214 more needed)
#     NA:  27/251 files ✗ INCOMPLETE (224 more needed)
#     NI:  53/251 files ✗ INCOMPLETE (198 more needed)
#     SI:  38/251 files ✗ INCOMPLETE (213 more needed)
#     AU:  41/251 files ✗ INCOMPLETE (210 more needed)
#     SP:  54/251 files ✗ INCOMPLETE (197 more needed)
#     WP:  37/251 files ✗ INCOMPLETE (214 more needed)
#
#   CMCC-ESM2/r1i1p1f1/historical/1987-2001
#     EP:  42/251 files ✗ INCOMPLETE (209 more needed)
#     NA:  77/251 files ✗ INCOMPLETE (174 more needed)
#     NI:  54/251 files ✗ INCOMPLETE (197 more needed)
#     SI:  49/251 files ✗ INCOMPLETE (202 more needed)
#     AU:  47/251 files ✗ INCOMPLETE (204 more needed)
#     SP:  49/251 files ✗ INCOMPLETE (202 more needed)
#     WP:  38/251 files ✗ INCOMPLETE (213 more needed)
#
#   CMCC-ESM2/r1i1p1f1/historical/2002-2014
#     EP:  46/251 files ✗ INCOMPLETE (205 more needed)
#     NA:  55/251 files ✗ INCOMPLETE (196 more needed)
#     NI:  53/251 files ✗ INCOMPLETE (198 more needed)
#     SI:  48/251 files ✗ INCOMPLETE (203 more needed)
#     AU:  46/251 files ✗ INCOMPLETE (205 more needed)
#     SP:  70/251 files ✗ INCOMPLETE (181 more needed)
#     WP:  46/251 files ✗ INCOMPLETE (205 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp126/2015-2026
#     EP:  48/251 files ✗ INCOMPLETE (203 more needed)
#     NA:  26/251 files ✗ INCOMPLETE (225 more needed)
#     NI:  71/251 files ✗ INCOMPLETE (180 more needed)
#     SI:  63/251 files ✗ INCOMPLETE (188 more needed)
#     AU:  70/251 files ✗ INCOMPLETE (181 more needed)
#     SP:  64/251 files ✗ INCOMPLETE (187 more needed)
#     WP:  37/251 files ✗ INCOMPLETE (214 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp126/2027-2036
#     EP:  51/251 files ✗ INCOMPLETE (200 more needed)
#     NA:  52/251 files ✗ INCOMPLETE (199 more needed)
#     NI:  69/251 files ✗ INCOMPLETE (182 more needed)
#     SI:  62/251 files ✗ INCOMPLETE (189 more needed)
#     AU:  69/251 files ✗ INCOMPLETE (182 more needed)
#     SP:  77/251 files ✗ INCOMPLETE (174 more needed)
#     WP:  64/251 files ✗ INCOMPLETE (187 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp126/2037-2046
#     EP:  47/251 files ✗ INCOMPLETE (204 more needed)
#     NA:  26/251 files ✗ INCOMPLETE (225 more needed)
#     NI:  84/251 files ✗ INCOMPLETE (167 more needed)
#     SI:  61/251 files ✗ INCOMPLETE (190 more needed)
#     AU:  61/251 files ✗ INCOMPLETE (190 more needed)
#     SP:  71/251 files ✗ INCOMPLETE (180 more needed)
#     WP:  55/251 files ✗ INCOMPLETE (196 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp126/2047-2058
#     EP:  40/251 files ✗ INCOMPLETE (211 more needed)
#     NA:  52/251 files ✗ INCOMPLETE (199 more needed)
#     NI:  58/251 files ✗ INCOMPLETE (193 more needed)
#     SI:  60/251 files ✗ INCOMPLETE (191 more needed)
#     AU:  48/251 files ✗ INCOMPLETE (203 more needed)
#     SP:  23/251 files ✗ INCOMPLETE (228 more needed)
#     WP:  21/251 files ✗ INCOMPLETE (230 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp126/2059-2076
#     EP: --- (folder doesn't exist) ✗ MISSING
#     NA: --- (folder doesn't exist) ✗ MISSING
#     NI: --- (folder doesn't exist) ✗ MISSING
#     SI: --- (folder doesn't exist) ✗ MISSING
#     AU: --- (folder doesn't exist) ✗ MISSING
#     SP: --- (folder doesn't exist) ✗ MISSING
#     WP: --- (folder doesn't exist) ✗ MISSING
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2015-2026
#     EP:  39/251 files ✗ INCOMPLETE (212 more needed)
#     NA:  44/251 files ✗ INCOMPLETE (207 more needed)
#     NI:  54/251 files ✗ INCOMPLETE (197 more needed)
#     SI:  48/251 files ✗ INCOMPLETE (203 more needed)
#     AU:  48/251 files ✗ INCOMPLETE (203 more needed)
#     SP:  61/251 files ✗ INCOMPLETE (190 more needed)
#     WP:  44/251 files ✗ INCOMPLETE (207 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2027-2036
#     EP:  56/251 files ✗ INCOMPLETE (195 more needed)
#     NA:  32/251 files ✗ INCOMPLETE (219 more needed)
#     NI:  81/251 files ✗ INCOMPLETE (170 more needed)
#     SI:  74/251 files ✗ INCOMPLETE (177 more needed)
#     AU:  69/251 files ✗ INCOMPLETE (182 more needed)
#     SP:  89/251 files ✗ INCOMPLETE (162 more needed)
#     WP:  74/251 files ✗ INCOMPLETE (177 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2037-2052
#     EP:  39/251 files ✗ INCOMPLETE (212 more needed)
#     NA:  29/251 files ✗ INCOMPLETE (222 more needed)
#     NI:  45/251 files ✗ INCOMPLETE (206 more needed)
#     SI:  39/251 files ✗ INCOMPLETE (212 more needed)
#     AU:  38/251 files ✗ INCOMPLETE (213 more needed)
#     SP:  46/251 files ✗ INCOMPLETE (205 more needed)
#     WP:  35/251 files ✗ INCOMPLETE (216 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2053-2065
#     EP:  29/251 files ✗ INCOMPLETE (222 more needed)
#     NA:  30/251 files ✗ INCOMPLETE (221 more needed)
#     NI:  57/251 files ✗ INCOMPLETE (194 more needed)
#     SI:  54/251 files ✗ INCOMPLETE (197 more needed)
#     AU:  50/251 files ✗ INCOMPLETE (201 more needed)
#     SP:  59/251 files ✗ INCOMPLETE (192 more needed)
#     WP:  48/251 files ✗ INCOMPLETE (203 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2066-2075
#     EP:  43/251 files ✗ INCOMPLETE (208 more needed)
#     NA:  30/251 files ✗ INCOMPLETE (221 more needed)
#     NI:  71/251 files ✗ INCOMPLETE (180 more needed)
#     SI:  66/251 files ✗ INCOMPLETE (185 more needed)
#     AU:  54/251 files ✗ INCOMPLETE (197 more needed)
#     SP:  71/251 files ✗ INCOMPLETE (180 more needed)
#     WP:  53/251 files ✗ INCOMPLETE (198 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2076-2090
#     EP:  29/251 files ✗ INCOMPLETE (222 more needed)
#     NA:  52/251 files ✗ INCOMPLETE (199 more needed)
#     NI:  17/251 files ✗ INCOMPLETE (234 more needed)
#     SI:  17/251 files ✗ INCOMPLETE (234 more needed)
#     AU:  16/251 files ✗ INCOMPLETE (235 more needed)
#     SP:  18/251 files ✗ INCOMPLETE (233 more needed)
#     WP:  52/251 files ✗ INCOMPLETE (199 more needed)
#
#   CMCC-ESM2/r1i1p1f1/ssp245/2091-2100
#     EP:  42/251 files ✗ INCOMPLETE (209 more needed)
#     NA:  41/251 files ✗ INCOMPLETE (210 more needed)
#     NI:  68/251 files ✗ INCOMPLETE (183 more needed)
#     SI:  71/251 files ✗ INCOMPLETE (180 more needed)
#     AU:  55/251 files ✗ INCOMPLETE (196 more needed)
#     SP:  71/251 files ✗ INCOMPLETE (180 more needed)
#     WP:  55/251 files ✗ INCOMPLETE (196 more needed)

# %% [markdown]
# ## TEST 4: Summary Statistics

# %%
# Count total individual basin tasks that need to be run
total_incomplete_basin_tasks = sum(len(task['incomplete_basins']) for task in level4_tasks_with_incomplete_basins)

print("\n" + "="*80)
print("=== COMPREHENSIVE SUMMARY ===")
print("="*80)

print(f"\nPipeline Status:")
print(f"\n  Level 3 (Global TC-Risk):")
print(f"    - Finished (ready for L4):    {len(level3_finished)}")
print(f"    - Not finished (skip L4):     {len(level3_not_finished)}")
print(f"    - Total:                      {len(all_tasks)}")

print(f"\n  Level 4 (Basin TC-Risk):")
print(f"    - Combos with incomplete basins: {len(level4_tasks_with_incomplete_basins)}")
print(f"    - Total individual basin tasks:  {total_incomplete_basin_tasks}")
print(f"    - Combos fully complete:         {len(level4_fully_complete)}")

# Distribution of file counts
print(f"\n  Level 4 Basin File Count Distribution:")
all_file_counts = []
for task in level4_tasks_with_incomplete_basins:
    for count in task['basin_file_counts'].values():
        if count >= 0:
            all_file_counts.append(count)

if all_file_counts:
    print(f"    - Min files in any basin:     {min(all_file_counts)}")
    print(f"    - Max files in any basin:     {max(all_file_counts)}")
    print(f"    - Average files per basin:    {sum(all_file_counts) / len(all_file_counts):.1f}")
    print(f"    - Required for completion:    {NUM_DRAWS + 1}")

# Empty basins (no folder)
empty_basins = sum(1 for task in level4_tasks_with_incomplete_basins 
                   for count in task['basin_file_counts'].values() 
                   if count == -1)
print(f"    - Basins with no folder:      {empty_basins}")

print(f"\nEstimated Runtime (if running):")
print(f"  - Level 4: ~{total_incomplete_basin_tasks * 120} minutes (assuming 120 min per basin task)")
print(f"            = ~{total_incomplete_basin_tasks * 120 / 60:.1f} hours")

# %% [markdown]
# ## TEST 5: Verify Path Structure and File Details

# %%
# Show sample completed and incomplete paths
print("\n=== SAMPLE PATHS ===")

if level3_finished:
    sample_task = level3_finished[0]
    sample_path = TC_RISK_OUTPUT_PATH / DATA_SOURCE / sample_task['model'] / sample_task['variant'] / sample_task['scenario'] / sample_task['time_period']
    print(f"\nSample Level 3 FINISHED path:")
    print(f"  {sample_path}")
    print(f"  Exists: {sample_path.exists()}")
    if sample_path.exists():
        all_files = list(sample_path.glob("*.nc"))
        env_wnd = list(sample_path.glob("env_wnd_*.nc"))
        thermo = list(sample_path.glob("thermo_*.nc"))
        print(f"  Total files: {len(all_files)}")
        print(f"  env_wnd_*.nc files: {len(env_wnd)}")
        print(f"  thermo_*.nc files: {len(thermo)}")

if level4_tasks_with_incomplete_basins:
    sample_task = level4_tasks_with_incomplete_basins[0]
    sample_basin = sample_task['incomplete_basins'][0]
    sample_path = TC_RISK_OUTPUT_PATH / DATA_SOURCE / sample_task['model'] / sample_task['variant'] / sample_task['scenario'] / sample_task['time_period'] / sample_basin
    print(f"\nSample Level 4 INCOMPLETE basin path:")
    print(f"  {sample_path}")
    print(f"  Exists: {sample_path.exists()}")
    if sample_path.exists():
        files = list(sample_path.glob("*.nc"))
        print(f"  File count: {len(files)}/{NUM_DRAWS + 1}")
        print(f"  Missing: {NUM_DRAWS + 1 - len(files)} files")
        if files:
            print(f"  Sample files:")
            for file in sorted(files)[:3]:
                print(f"    - {file.name}")
            if len(files) > 3:
                print(f"    ... and {len(files) - 3} more")
